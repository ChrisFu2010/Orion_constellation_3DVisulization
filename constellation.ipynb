# %% [markdown]
# ## Project: Visualizing the Orion Constellation
#
# Visulize Constellation Orion, a collection of stars that appear in our night sky and form the shape of [Orion](https://en.wikipedia.org/wiki/Orion_(constellation))
#
# Create a rotate-able visulization of Orion's stars.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/9/91/Orion_constellation_with_star_labels.jpg" alt="Orion" style="width: 400px;"/>

# %%
# matplotlib enables rotate visualization in jupyter notebook
# %matplotlib notebook
from matplotlib import pyplot as plt
# import 3D visualization from mpl_toolkits
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Data
#
# The `x`, `y`, and `z` lists below are composed of the x, y, z coordinates for each star in the collection of stars that make up the Orion constellation as documented in a paper by Nottingham Trent Univesity on "The Orion constellation as an installation" found [here](https://arxiv.org/ftp/arxiv/papers/1110/1110.3469.pdf).

# %%
# Orion
x = [-0.41, 0.57, 0.07, 0.00, -0.29, -0.32,-0.50,-0.23, -0.23]
y = [4.12, 7.71, 2.36, 9.10, 13.35, 8.13, 7.19, 13.25,13.43]
z = [2.06, 0.84, 1.56, 2.07, 2.36, 1.72, 0.66, 1.25,1.38]

# %% [markdown]
# ## Create a 2D Visualization
#
# Create 2D visulization using scatter map.

# %%
fig = plt.figure()
constellation2d = plt.subplot(1,1,1)
constellation2d.scatter(x,y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 4. Create a 3D Visualization
#
# Create 3D Visulization

# %%
fig_3d = plt.figure()
constellation3d = plt.subplot(1,1,1,projection="3d")
constellation3d.scatter(x,y,z)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## You can rotate and explore Orion!
#
# Use your mouse to click and drag the 3D visualization in the 3D graphic. This will rotate the scatter plot.
